# %%
import pandas as pd
import numpy as np
import pyspark as ps
from pyspark.sql import SparkSession
from pyspark.sql.types import (
    IntegerType, StringType, IntegerType, FloatType, 
    StructField, StructType, DoubleType
)
from pyspark.ml.recommendation import ALS
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from pyspark.sql.functions import udf, col, isnan
import psycopg2
from pandas.io import sql
from sklearn.model_selection import train_test_split
from pyspark.ml.evaluation import RegressionEvaluator

# %%
conn = psycopg2.connect(dbname='mixmaker', host='localhost')
cur = conn.cursor()

# %%
query = 'SELECT * FROM artists;'
artists = sql.read_sql_query(query, conn)

# %%
artists.head()
# Out:
#    id                    name  \
# 0  13             Isaac Hayes
# 1  14  KC & the Sunshine Band
# 2  15           Stevie Wonder
# 3  16      Earth, Wind & Fire
# 4  17                Bee Gees
#
#                                                  url  scraped
# 0            https://www.whosampled.com/Isaac-Hayes/        0
# 1  https://www.whosampled.com/KC-%26-the-Sunshine...        0
# 2          https://www.whosampled.com/Stevie-Wonder/        0
# 3   https://www.whosampled.com/Earth,-Wind-%26-Fire/        0
# 4               https://www.whosampled.com/Bee-Gees/        0

# %%
query = 'SELECT * FROM songs;'
songs = sql.read_sql_query(query, conn)

# %%
len(songs)
# Out:
# 29231

# %%
query = 'SELECT * FROM connections;'
connections = sql.read_sql_query(query, conn)

# %%
connections = connections.drop('remixed_by_song_id', axis=1)

# %%
connections['is_connected'] = np.ones(len(connections))

# %%
connections.head()
# Out:
#    song_id  sampled_by_song_id  is_connected
# 0        1                 374           1.0
# 1        1                 375           1.0
# 2        1                 376           1.0
# 3        1                 377           1.0
# 4        1                 378           1.0

# %%
spark_df = spark.createDataFrame(connections)

# %%
train, test = spark_df.randomSplit([0.8, 0.2], seed=216)

# %%
als_model = ALS(
    itemCol='song_id',
    userCol='sampled_by_song_id',
    ratingCol='is_connected',
    nonnegative=True,
    regParam=0.01,
    rank=10,
    implicitPrefs=True)

recommender = als_model.fit(train)

test_predictions = recommender.transform(test)

# %%
test_predictions.show()
# Out:
# +-------+------------------+------------+------------+
# |song_id|sampled_by_song_id|is_connected|  prediction|
# +-------+------------------+------------+------------+
# |    463|              9170|         1.0|         NaN|
# |    471|              9896|         1.0| 7.016704E-7|
# |    471|              9170|         1.0|4.4592525E-6|
# |  13285|             14299|         1.0|         NaN|
# |  14570|             14987|         1.0|0.0026822868|
# |    392|              9170|         1.0|         0.0|
# |  11280|             11800|         1.0|         NaN|
# |  11280|             11713|         1.0|         NaN|
# |  11280|             11835|         1.0|  0.01750579|
# |  11280|             11808|         1.0|         NaN|
# |  11280|             11694|         1.0|         NaN|
# |  11280|             11736|         1.0|         NaN|
# |  11280|             11717|         1.0|         NaN|
# |  11280|              1125|         1.0|         NaN|
# |  11280|             11764|         1.0|         NaN|
# |  11280|             11805|         1.0|         NaN|
# |  11280|             11718|         1.0|         NaN|
# |  11280|             11659|         1.0|         0.0|
# |  11280|             11771|         1.0|         NaN|
# |  11280|             11752|         1.0|         NaN|
# +-------+------------------+------------+------------+
# only showing top 20 rows

# %%
preds_df = test_predictins.toPandas()

# %%
preds_df.head()
# Out:
#    song_id  sampled_by_song_id  is_connected  prediction
# 0      463                9170           1.0         NaN
# 1      471                9896           1.0    0.609067
# 2      471                9170           1.0    0.505995
# 3    13285               14299           1.0         NaN
# 4    14570               14987           1.0    0.610512

# %%
check = preds_df.sort_values('prediction', ascending=False).head(10)

# %%
lookup_id = 612
lookup_df = preds_df.loc[preds_df['sampled_by_song_id']==lookup_id,:]

# %%
lookup_df.sort_values('prediction', ascending=False).head()
# Out:
#       song_id  sampled_by_song_id  is_connected  prediction
# 262        28                 612           1.0    1.257137
# 841      9152                 612           1.0    1.076854
# 3387       83                 612           1.0    1.069884
# 3492       42                 612           1.0    1.061826
# 1655       20                 612           1.0    1.035928

# %%
songs[songs['name'] == 'All Night']
# Out:
#           id  artist_id       name  \
# 2188    2214       1324  All Night
# 4535    4563       2758  All Night
# 13413  13428       4207  All Night
# 15351  15368       6788  All Night
# 15366  15383       6798  All Night
#
#                                                      url  scraped
# 2188         https://www.whosampled.com/Milira/All-Night        0
# 4535   https://www.whosampled.com/Maurice-Tamraz/All-...        0
# 13413  https://www.whosampled.com/Angelo-Ferreri/All-...        0
# 15351  https://www.whosampled.com/Luxury-Elite/All-Night        0
# 15366        https://www.whosampled.com/Cinque/All-Night        0

# %%
artists.loc[artists['name'].apply(lambda x: x.startswith('Beyonc'))]
# Out:
#         id     name                                       url  scraped
# 6907  6908  Beyoncé  https://www.whosampled.com/Beyonc%C3%A9/        0

# %%
songs[songs['artist_id'] == 6908]
# Out:
#           id  artist_id           name  \
# 15559  15579       6908  Black Culture
#
#                                                      url  scraped
# 15559  https://www.whosampled.com/Beyonc%C3%A9/Black-...        0

# %%
preds_df.sort_values('prediction', ascending=False).head(10)
# Out:
#       song_id  sampled_by_song_id  is_connected  prediction
# 3908      134                 421           1.0    1.293696
# 2993     9774                4652           1.0    1.288245
# 112        65                1471           1.0    1.280834
# 2851       82                4064           1.0    1.276294
# 2149        9                 627           1.0    1.264793
# 262        28                 612           1.0    1.257137
# 90         31                2830           1.0    1.254280
# 1748      120                3331           1.0    1.212860
# 222        34                2599           1.0    1.210035
# 110        65                2297           1.0    1.203673

# %%
als_model = ALS(
    itemCol='song_id',
    userCol='sampled_by_song_id',
    ratingCol='is_connected',
    nonnegative=True,
    alpha = 0.1,
    regParam=0.01,

    rank=50)

recommender = als_model.fit(train)

# %%
train_preds = recommender.transform(train)

# %%
evaluator = RegressionEvaluator(metricName='rmse', 
                                labelCol='is_connected',
                                predictionCol='prediction')

# %%
rmse_train = evaluator.evaluate(train_preds)

# %%
rmse_train
# Out:
# 0.0174042459623237

# %%
lookup_id = 627
lookup_df = preds_df.loc[preds_df['sampled_by_song_id']==lookup_id,:]
songs[songs['id'] == lookup_id]
# Out:
#       id  artist_id           name  \
# 599  627        251  Keep on Doin'
#
#                                                    url  scraped
# 599  https://www.whosampled.com/Kev-E-Kev/Keep-on-D...        0

# %%
test_predictions = recommender.transform(test)

# %%
rmse = evaluator.evaluate(test_predictions)

# %%
rmse_test = evaluator.evaluate(
    test_predictions.filter("prediction + 1 > prediction"))

# %%
rmse_test
# Out:
# 0.131964625788508

# %%
test_predictions.filter("prediction + 1 > prediction").count()
# Out:
# 9851

# %%
test_predictions.count()
# Out:
# 12605

# %%
test_predictions.persist().count()
# Out:
# 3967

# %%
cd /Users/brettashley/galvanize/dsi/00-Capstone/mix-maker/src
# Out:
# /Users/brettashley/galvanize/dsi/00-Capstone/mix-maker/src

# %%
import model

# %%
sr = model.SongRecommender()

# %%
df.columns
# Out:
# Index(['song_id', 'sampled_by_song_id', 'is_connected', 'prediction'], dtype='object')

# %%
new_df = pd.DataFrame(new, columns=df.columns[:2])

# %%
new_df['is_connected'] = 0

# %%
new_df.head()
# Out:
#    song_id  sampled_by_song_id  is_connected
# 0     9767                2815             0
# 1    14456               10660             0
# 2    14396                2404             0
# 3       94                4005             0
# 4       83                9523             0

# %%
test_pd = test.toPandas()

# %%
test_pd.head()
# Out:
#    song_id  sampled_by_song_id  is_connected
# 0        1                 374           1.0
# 1        1                 376           1.0
# 2        1                 378           1.0
# 3        1                 382           1.0
# 4        1                 383           1.0

# %%
check = pd.concat([test_pd, new_df]).reset_index()

# %%
sr.generate_negative_targets(test,
                             'song_id',
                             'sampled_by_song_id',
                             'is_connected',
                             seed=406)
# Out:
# DataFrame[index: bigint, is_connected: double, sampled_by_song_id: bigint, song_id: bigint]

# %%
test_with_neg = _

# %%
test_with_neg.limit(10).show()
# Out:
# +-----+------------+------------------+-------+
# |index|is_connected|sampled_by_song_id|song_id|
# +-----+------------+------------------+-------+
# |    0|         1.0|               374|      1|
# |    1|         1.0|               376|      1|
# |    2|         1.0|               378|      1|
# |    3|         1.0|               382|      1|
# |    4|         1.0|               383|      1|
# |    5|         1.0|               391|      1|
# |    6|         1.0|               397|      1|
# |    7|         1.0|               403|      1|
# |    8|         1.0|               410|      1|
# |    9|         1.0|               422|      1|
# +-----+------------+------------------+-------+

# %%
test_with_neg.count()
# Out:
# 25210

# %%
preds = recommender.transform(test_with_neg)

# %%
sr.RMSE(preds, has_nan_values=True)
# Out:
# 0.6702252586102077

# %%
preds_df = preds.toPandas()

# %%
preds_df.columns
# Out:
# Index(['index', 'is_connected', 'sampled_by_song_id', 'song_id', 'prediction'], dtype='object')

# %%
df = preds_df.loc[preds_df['is_connected'] == 0,:]
checks = df.sort_values('prediction', ascending=False).head(100)

# %%
checks.head()
# Out:
#        index  is_connected  sampled_by_song_id  song_id  prediction
# 11889  10904           0.0                4992    17487    2.117134
# 245     5667           0.0               24455    14377    2.006908
# 23227  12067           0.0                4585    13202    1.951384
# 11898   6007           0.0               23580    17487    1.924200
# 7962    8196           0.0               25257    16088    1.889433

# %%
check_merge_song1 = (checks.merge(songs, left_on='song_id', right_on='id')
                     .drop(columns=['artist_id', 'id', 'scraped', 'index'], axis=1))

# %%
check_merge_songs = (check_merge_song1.merge(songs, left_on='sampled_by_song_id', right_on='id')
    .drop(columns=['artist_id', 'id', 'scraped', 'is_connected'], axis=1))

# %%
check_merge_songs
# Out:
#     sampled_by_song_id  song_id  prediction  \
# 0                 4992    17487    2.117134
# 1                23580    17487    1.924200
# 2                23580     9784    1.597071
# 3                24455    14377    2.006908
# 4                 4585    13202    1.951384
# 5                25257    16088    1.889433
# 6                24352    16088    1.680222
# 7                 4913     9790    1.874424
# 8                10035     9790    1.583541
# 9                 3783    12206    1.849226
# 10               19710    12206    1.740701
# 11               24248    12206    1.681135
# 12               23430    12206    1.681135
# 13                8429    12206    1.678731
# 14               24797     9828    1.807970
# 15               22890    14349    1.798473
# 16               23030    14349    1.798473
# 17                3237    13186    1.795475
# 18                8448    13186    1.632439
# 19               25293    26314    1.795041
# 20                2774    16071    1.792758
# 21               23057    16071    1.671165
# 22               23057    27732    1.591361
# 23               24018     9770    1.785866
# 24               24018      459    1.609648
# 25               20285     1541    1.765320
# 26               23233    16069    1.754366
# 27                3833    12064    1.744545
# 28                4359    20070    1.743140
# 29               25331      104    1.732431
# ..                 ...      ...         ...
# 70               23927    27739    1.614343
# 71               23108    27739    1.609333
# 72               23526    17973    1.612203
# 73               24273    17490    1.611701
# 74               25039    27728    1.609739
# 75               24179    27728    1.583517
# 76               24156    28812    1.609311
# 77                3072    12175    1.606941
# 78                3878    11291    1.606060
# 79                5620     8039    1.605734
# 80                4990     1523    1.605351
# 81                 778    12161    1.604740
# 82                 778    26321    1.584454
# 83               21290    13215    1.603154
# 84               24254    10317    1.599188
# 85               24811    10317    1.599188
# 86               23598     9784    1.597071
# 87               25265     9784    1.597071
# 88               24588     9784    1.594853
# 89               23280     9784    1.594853
# 90                4939    26310    1.595895
# 91                4936    26321    1.591041
# 92               23315     4389    1.587500
# 93               22917     4275    1.586972
# 94               23011       48    1.583968
# 95               24462    14849    1.581076
# 96               23197    14524    1.580665
# 97               23753    14732    1.580283
# 98               24672    14732    1.580283
# 99               25332    16718    1.580132
#
#                                                name_x  \
# 0                             I Want Your Love (1978)
# 1                             I Want Your Love (1978)
# 2                               Get Down on It (1981)
# 3   Somebody's Watching Me (1983)\nby Rockwell fea...
# 4                              Let's Get It On (1973)
# 5                          The Big Bang Theory (1979)
# 6                          The Big Bang Theory (1979)
# 7                                Ladies' Night (1979)
# 8                                Ladies' Night (1979)
# 9                           A Hard Day's Night (1964)
# 10                          A Hard Day's Night (1964)
# 11                          A Hard Day's Night (1964)
# 12                          A Hard Day's Night (1964)
# 13                          A Hard Day's Night (1964)
# 14                                     Megamix (1983)
# 15                 P.Y.T. (Pretty Young Thing) (1982)
# 16                 P.Y.T. (Pretty Young Thing) (1982)
# 17                           Got to Give It Up (1977)
# 18                           Got to Give It Up (1977)
# 19                               Home Computer (1981)
# 20                             Funkin' for Fun (1976)
# 21                             Funkin' for Fun (1976)
# 22                              Beastie Groove (1985)
# 23
# 24                                          Hey Fonzo
# 25                              Three MC's and One DJ
# 26                             Dr. Funkenstein (1975)
# 27                                      Do That Stuff
# 28                                    Posse in Effect
# 29               Down and Out in New York City (1973)
# ..                                                ...
# 70                                 Jimmy James (1992)
# 71                                 Jimmy James (1992)
# 72                           B Side Wins Again (1990)
# 73                          My Forbidden Lover (1979)
# 74  Get It Together (1994)\nby Beastie Boys feat. ...
# 75  Get It Together (1994)\nby Beastie Boys feat. ...
# 76                        If I Ruled the World (1985)
# 77                            Yellow Submarine (1966)
# 78                           Freak of the Week (1979)
# 79                   Dis Yourself in '89 (Just Do It)
# 80                                           Shadrach
# 81                               Come Together (1969)
# 82                            Musique Non Stop (1986)
# 83                     Time to Get It Together (1978)
# 84                                  B Side Wins Again
# 85                                  B Side Wins Again
# 86                              Get Down on It (1981)
# 87                              Get Down on It (1981)
# 88                              Get Down on It (1981)
# 89                              Get Down on It (1981)
# 90                                  The Robots (1978)
# 91                            Musique Non Stop (1986)
# 92                                           The Ave.
# 93       The Michael Jackson Medley (Ultimix Megamix)
# 94  (It's Not the Express) It's the J.B.'s Monaura...
# 95                      The Dangerous New Jack Medley
# 96  The Michael Jackson Medley (Ultimix Megamix) (...
# 97                       25 Years on Sony Pt.1 (2009)
# 98                       25 Years on Sony Pt.1 (2009)
# 99  Get It Up (1981)\nby The Time\nProducer credit...
#
#                                                 url_x  \
# 0   https://www.whosampled.com/Chic/I-Want-Your-Love/
# 1   https://www.whosampled.com/Chic/I-Want-Your-Love/
# 2   https://www.whosampled.com/Kool-%26-the-Gang/G...
# 3   https://www.whosampled.com/Rockwell/Somebody%2...
# 4   https://www.whosampled.com/Marvin-Gaye/Let%27s...
# 5   https://www.whosampled.com/Parliament/The-Big-...
# 6   https://www.whosampled.com/Parliament/The-Big-...
# 7   https://www.whosampled.com/Kool-%26-the-Gang/L...
# 8   https://www.whosampled.com/Kool-%26-the-Gang/L...
# 9   https://www.whosampled.com/The-Beatles/A-Hard-...
# 10  https://www.whosampled.com/The-Beatles/A-Hard-...
# 11  https://www.whosampled.com/The-Beatles/A-Hard-...
# 12  https://www.whosampled.com/The-Beatles/A-Hard-...
# 13  https://www.whosampled.com/The-Beatles/A-Hard-...
# 14  https://www.whosampled.com/Kool-%26-the-Gang/M...
# 15  https://www.whosampled.com/Michael-Jackson/P.Y...
# 16  https://www.whosampled.com/Michael-Jackson/P.Y...
# 17  https://www.whosampled.com/Marvin-Gaye/Got-to-...
# 18  https://www.whosampled.com/Marvin-Gaye/Got-to-...
# 19  https://www.whosampled.com/Kraftwerk/Home-Comp...
# 20  https://www.whosampled.com/Parliament/Funkin%2...
# 21  https://www.whosampled.com/Parliament/Funkin%2...
# 22  https://www.whosampled.com/Beastie-Boys/Beasti...
# 23  https://www.whosampled.com/Kool-%26-the-Gang/W...
# 24          https://www.whosampled.com/Mito/Hey-Fonzo
# 25  https://www.whosampled.com/Beastie-Boys/Three-...
# 26  https://www.whosampled.com/Parliament/Dr.-Funk...
# 27  https://www.whosampled.com/Parliament/Do-That-...
# 28  https://www.whosampled.com/Beastie-Boys/Posse-...
# 29  https://www.whosampled.com/James-Brown/Down-an...
# ..                                                ...
# 70  https://www.whosampled.com/Beastie-Boys/Jimmy-...
# 71  https://www.whosampled.com/Beastie-Boys/Jimmy-...
# 72  https://www.whosampled.com/Public-Enemy/B-Side...
# 73  https://www.whosampled.com/Chic/My-Forbidden-L...
# 74  https://www.whosampled.com/Beastie-Boys/Get-It...
# 75  https://www.whosampled.com/Beastie-Boys/Get-It...
# 76  https://www.whosampled.com/Kurtis-Blow/If-I-Ru...
# 77  https://www.whosampled.com/The-Beatles/Yellow-...
# 78  https://www.whosampled.com/Funkadelic/Freak-of...
# 79  https://www.whosampled.com/Beastie-Boys/Dis-Yo...
# 80   https://www.whosampled.com/Beastie-Boys/Shadrach
# 81  https://www.whosampled.com/The-Beatles/Come-To...
# 82  https://www.whosampled.com/Kraftwerk/Musique-N...
# 83  https://www.whosampled.com/Marvin-Gaye/Time-to...
# 84  https://www.whosampled.com/Public-Enemy/B-Side...
# 85  https://www.whosampled.com/Public-Enemy/B-Side...
# 86  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 87  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 88  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 89  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 90   https://www.whosampled.com/Kraftwerk/The-Robots/
# 91  https://www.whosampled.com/Kraftwerk/Musique-N...
# 92        https://www.whosampled.com/Run-DMC/The-Ave.
# 93  https://www.whosampled.com/Michael-Jackson/The...
# 94  https://www.whosampled.com/The-J.B.%27s/(It%27...
# 95  https://www.whosampled.com/Michael-Jackson/The...
# 96  https://www.whosampled.com/Michael-Jackson/The...
# 97  https://www.whosampled.com/Michael-Jackson/25-...
# 98  https://www.whosampled.com/Michael-Jackson/25-...
# 99     https://www.whosampled.com/The-Time/Get-It-Up/
#
#                                               name_y  \
# 0                                        Murda Style
# 1                                          Mechanics
# 2                                          Mechanics
# 3                                            MXXXIII
# 4                                       Crystal Cuts
# 5                                         Conquering
# 6                           Tribal Connections Pt. 2
# 7                                           Deranged
# 8                                         Lights Out
# 9                                            So Long
# 10                               Hawt (Getter Remix)
# 11                            Enuff (DJ Fresh Remix)
# 12                                     Military Jazz
# 13                                         Gunrunner
# 14                                     Seventh Sound
# 15                                            Stylee
# 16                                      Angel Voices
# 17                                    No Time 2 Love
# 18                                      The Violater
# 19                                        Prominence
# 20                                   Marche À Suivre
# 21                                     Magoo Opening
# 22                                     Magoo Opening
# 23                                       Party Alarm
# 24                                       Party Alarm
# 25                                             Fotki
# 26                                 How Does It Feel?
# 27                                           Shimmer
# 28                      Fire (Urban Shakedown Remix)
# 29                                        The Dragon
# ..                                               ...
# 70                                          Analysis
# 71                 La Formule Secrète II: Le Retour!
# 72                                    Taken to Heart
# 73                                  Southern Comfort
# 74                                      Still Waters
# 75                        Crimson Stars First Lesson
# 76                                         2 Pumpin'
# 77                          The Bonnie & Clyde Theme
# 78                                           Feel It
# 79                                      Rough Luxury
# 80                       Protection (DJ Narcs Remix)
# 81                                          Lesson 4
# 82                                          Lesson 4
# 83                             Dziękuj Za to Co Masz
# 84                                        Understand
# 85                                            Volcon
# 86                                     Are You Ready
# 87                                   Talking to Gods
# 88                                          Ratatata
# 89                    Ultrafunkula (Ganja Kru Remix)
# 90                                        Footprints
# 91                           Blessings (For My Baby)
# 92                                           Aaron 2
# 93  Under Mi Sensi (Jungle Spliff) (X Project Remix)
# 94                                   Inna Year 3,000
# 95                                        Omega Amen
# 96                                          Break In
# 97   Only When I Lose Myself (Subsonic Legacy Remix)
# 98                                         Reel Funk
# 99                                          Time War
#
#                                                 url_y
# 0      https://www.whosampled.com/Kid-Lib/Murda-Style
# 1   https://www.whosampled.com/Dom-%26-Roland/Mech...
# 2   https://www.whosampled.com/Dom-%26-Roland/Mech...
# 3   https://www.whosampled.com/DJ-Groove-(Russia)/...
# 4       https://www.whosampled.com/Sully/Crystal-Cuts
# 5      https://www.whosampled.com/Acid-Lab/Conquering
# 6   https://www.whosampled.com/DJ-Crazee-M/Tribal-...
# 7   https://www.whosampled.com/Special-Request/Der...
# 8   https://www.whosampled.com/III-Most-Wanted/Lig...
# 9             https://www.whosampled.com/Seba/So-Long
# 10  https://www.whosampled.com/Brillz/Hawt-%28Gett...
# 11  https://www.whosampled.com/DJ-Shadow/Enuff-%28...
# 12      https://www.whosampled.com/Plug/Military-Jazz
# 13  https://www.whosampled.com/Gabriel-(Drum-%26-B...
# 14     https://www.whosampled.com/Anile/Seventh-Sound
# 15    https://www.whosampled.com/Soundmurderer/Stylee
# 16  https://www.whosampled.com/Virtual-Self/Angel-...
# 17  https://www.whosampled.com/DJ-Marky/No-Time-2-...
# 18  https://www.whosampled.com/Resonant-Evil/The-V...
# 19     https://www.whosampled.com/Stranjah/Prominence
# 20  https://www.whosampled.com/Sens-Unik/Marche-%C...
# 21  https://www.whosampled.com/Cornelius/Magoo-Ope...
# 22  https://www.whosampled.com/Cornelius/Magoo-Ope...
# 23    https://www.whosampled.com/Downlink/Party-Alarm
# 24    https://www.whosampled.com/Downlink/Party-Alarm
# 25  https://www.whosampled.com/Pijani-Powietrzem/F...
# 26  https://www.whosampled.com/Electroset/How-Does...
# 27   https://www.whosampled.com/Source-Direct/Shimmer
# 28  https://www.whosampled.com/Prizna/Fire-%28Urba...
# 29  https://www.whosampled.com/John-Rolodex/The-Dr...
# ..                                                ...
# 70  https://www.whosampled.com/Technical-Itch/Anal...
# 71  https://www.whosampled.com/Assassin/La-Formule...
# 72      https://www.whosampled.com/KCF/Taken-to-Heart
# 73  https://www.whosampled.com/Innervisions/Southe...
# 74  https://www.whosampled.com/Basic-Influence/Sti...
# 75  https://www.whosampled.com/Dr.-Mario/Crimson-S...
# 76  https://www.whosampled.com/2-Croozin%27/2-Pump...
# 77  https://www.whosampled.com/Yo-Yo/The-Bonnie-%2...
# 78   https://www.whosampled.com/Law-%26-Auder/Feel-It
# 79     https://www.whosampled.com/L.O.E./Rough-Luxury
# 80  https://www.whosampled.com/DannyLO/Protection-...
# 81      https://www.whosampled.com/DJ-Shadow/Lesson-4
# 82      https://www.whosampled.com/DJ-Shadow/Lesson-4
# 83  https://www.whosampled.com/Szybki-Szmal/Dzi%C4...
# 84      https://www.whosampled.com/Om-Unit/Understand
# 85          https://www.whosampled.com/Dub-One/Volcon
# 86  https://www.whosampled.com/Sy-%26-Unknown/Are-...
# 87  https://www.whosampled.com/Invisible-Landscape...
# 88       https://www.whosampled.com/Deadcode/Ratatata
# 89  https://www.whosampled.com/Armand-Van-Helden/U...
# 90  https://www.whosampled.com/Spirit-(Drum-%26-Ba...
# 91  https://www.whosampled.com/Jonny-Dangerously/B...
# 92  https://www.whosampled.com/Venetian-Snares/Aar...
# 93  https://www.whosampled.com/Barrington-Levy/Und...
# 94  https://www.whosampled.com/DJ-Crystl/Inna-Year...
# 95    https://www.whosampled.com/Southstar/Omega-Amen
# 96         https://www.whosampled.com/Cirrus/Break-In
# 97  https://www.whosampled.com/Depeche-Mode/Only-W...
# 98  https://www.whosampled.com/Northern-Connexion/...
# 99    https://www.whosampled.com/Evol-Intent/Time-War
#
# [100 rows x 7 columns]

# %%
check_merge_songs.columns = ['sampled_by_song_id', 'song_id',
                             'prediction', 'sample_name',
                             'sample_url', 'song_name',
                             'song_url']

# %%
check_merge_songs
# Out:
#     sampled_by_song_id  song_id  prediction  \
# 0                 4992    17487    2.117134
# 1                23580    17487    1.924200
# 2                23580     9784    1.597071
# 3                24455    14377    2.006908
# 4                 4585    13202    1.951384
# 5                25257    16088    1.889433
# 6                24352    16088    1.680222
# 7                 4913     9790    1.874424
# 8                10035     9790    1.583541
# 9                 3783    12206    1.849226
# 10               19710    12206    1.740701
# 11               24248    12206    1.681135
# 12               23430    12206    1.681135
# 13                8429    12206    1.678731
# 14               24797     9828    1.807970
# 15               22890    14349    1.798473
# 16               23030    14349    1.798473
# 17                3237    13186    1.795475
# 18                8448    13186    1.632439
# 19               25293    26314    1.795041
# 20                2774    16071    1.792758
# 21               23057    16071    1.671165
# 22               23057    27732    1.591361
# 23               24018     9770    1.785866
# 24               24018      459    1.609648
# 25               20285     1541    1.765320
# 26               23233    16069    1.754366
# 27                3833    12064    1.744545
# 28                4359    20070    1.743140
# 29               25331      104    1.732431
# ..                 ...      ...         ...
# 70               23927    27739    1.614343
# 71               23108    27739    1.609333
# 72               23526    17973    1.612203
# 73               24273    17490    1.611701
# 74               25039    27728    1.609739
# 75               24179    27728    1.583517
# 76               24156    28812    1.609311
# 77                3072    12175    1.606941
# 78                3878    11291    1.606060
# 79                5620     8039    1.605734
# 80                4990     1523    1.605351
# 81                 778    12161    1.604740
# 82                 778    26321    1.584454
# 83               21290    13215    1.603154
# 84               24254    10317    1.599188
# 85               24811    10317    1.599188
# 86               23598     9784    1.597071
# 87               25265     9784    1.597071
# 88               24588     9784    1.594853
# 89               23280     9784    1.594853
# 90                4939    26310    1.595895
# 91                4936    26321    1.591041
# 92               23315     4389    1.587500
# 93               22917     4275    1.586972
# 94               23011       48    1.583968
# 95               24462    14849    1.581076
# 96               23197    14524    1.580665
# 97               23753    14732    1.580283
# 98               24672    14732    1.580283
# 99               25332    16718    1.580132
#
#                                           sample_name  \
# 0                             I Want Your Love (1978)
# 1                             I Want Your Love (1978)
# 2                               Get Down on It (1981)
# 3   Somebody's Watching Me (1983)\nby Rockwell fea...
# 4                              Let's Get It On (1973)
# 5                          The Big Bang Theory (1979)
# 6                          The Big Bang Theory (1979)
# 7                                Ladies' Night (1979)
# 8                                Ladies' Night (1979)
# 9                           A Hard Day's Night (1964)
# 10                          A Hard Day's Night (1964)
# 11                          A Hard Day's Night (1964)
# 12                          A Hard Day's Night (1964)
# 13                          A Hard Day's Night (1964)
# 14                                     Megamix (1983)
# 15                 P.Y.T. (Pretty Young Thing) (1982)
# 16                 P.Y.T. (Pretty Young Thing) (1982)
# 17                           Got to Give It Up (1977)
# 18                           Got to Give It Up (1977)
# 19                               Home Computer (1981)
# 20                             Funkin' for Fun (1976)
# 21                             Funkin' for Fun (1976)
# 22                              Beastie Groove (1985)
# 23
# 24                                          Hey Fonzo
# 25                              Three MC's and One DJ
# 26                             Dr. Funkenstein (1975)
# 27                                      Do That Stuff
# 28                                    Posse in Effect
# 29               Down and Out in New York City (1973)
# ..                                                ...
# 70                                 Jimmy James (1992)
# 71                                 Jimmy James (1992)
# 72                           B Side Wins Again (1990)
# 73                          My Forbidden Lover (1979)
# 74  Get It Together (1994)\nby Beastie Boys feat. ...
# 75  Get It Together (1994)\nby Beastie Boys feat. ...
# 76                        If I Ruled the World (1985)
# 77                            Yellow Submarine (1966)
# 78                           Freak of the Week (1979)
# 79                   Dis Yourself in '89 (Just Do It)
# 80                                           Shadrach
# 81                               Come Together (1969)
# 82                            Musique Non Stop (1986)
# 83                     Time to Get It Together (1978)
# 84                                  B Side Wins Again
# 85                                  B Side Wins Again
# 86                              Get Down on It (1981)
# 87                              Get Down on It (1981)
# 88                              Get Down on It (1981)
# 89                              Get Down on It (1981)
# 90                                  The Robots (1978)
# 91                            Musique Non Stop (1986)
# 92                                           The Ave.
# 93       The Michael Jackson Medley (Ultimix Megamix)
# 94  (It's Not the Express) It's the J.B.'s Monaura...
# 95                      The Dangerous New Jack Medley
# 96  The Michael Jackson Medley (Ultimix Megamix) (...
# 97                       25 Years on Sony Pt.1 (2009)
# 98                       25 Years on Sony Pt.1 (2009)
# 99  Get It Up (1981)\nby The Time\nProducer credit...
#
#                                            sample_url  \
# 0   https://www.whosampled.com/Chic/I-Want-Your-Love/
# 1   https://www.whosampled.com/Chic/I-Want-Your-Love/
# 2   https://www.whosampled.com/Kool-%26-the-Gang/G...
# 3   https://www.whosampled.com/Rockwell/Somebody%2...
# 4   https://www.whosampled.com/Marvin-Gaye/Let%27s...
# 5   https://www.whosampled.com/Parliament/The-Big-...
# 6   https://www.whosampled.com/Parliament/The-Big-...
# 7   https://www.whosampled.com/Kool-%26-the-Gang/L...
# 8   https://www.whosampled.com/Kool-%26-the-Gang/L...
# 9   https://www.whosampled.com/The-Beatles/A-Hard-...
# 10  https://www.whosampled.com/The-Beatles/A-Hard-...
# 11  https://www.whosampled.com/The-Beatles/A-Hard-...
# 12  https://www.whosampled.com/The-Beatles/A-Hard-...
# 13  https://www.whosampled.com/The-Beatles/A-Hard-...
# 14  https://www.whosampled.com/Kool-%26-the-Gang/M...
# 15  https://www.whosampled.com/Michael-Jackson/P.Y...
# 16  https://www.whosampled.com/Michael-Jackson/P.Y...
# 17  https://www.whosampled.com/Marvin-Gaye/Got-to-...
# 18  https://www.whosampled.com/Marvin-Gaye/Got-to-...
# 19  https://www.whosampled.com/Kraftwerk/Home-Comp...
# 20  https://www.whosampled.com/Parliament/Funkin%2...
# 21  https://www.whosampled.com/Parliament/Funkin%2...
# 22  https://www.whosampled.com/Beastie-Boys/Beasti...
# 23  https://www.whosampled.com/Kool-%26-the-Gang/W...
# 24          https://www.whosampled.com/Mito/Hey-Fonzo
# 25  https://www.whosampled.com/Beastie-Boys/Three-...
# 26  https://www.whosampled.com/Parliament/Dr.-Funk...
# 27  https://www.whosampled.com/Parliament/Do-That-...
# 28  https://www.whosampled.com/Beastie-Boys/Posse-...
# 29  https://www.whosampled.com/James-Brown/Down-an...
# ..                                                ...
# 70  https://www.whosampled.com/Beastie-Boys/Jimmy-...
# 71  https://www.whosampled.com/Beastie-Boys/Jimmy-...
# 72  https://www.whosampled.com/Public-Enemy/B-Side...
# 73  https://www.whosampled.com/Chic/My-Forbidden-L...
# 74  https://www.whosampled.com/Beastie-Boys/Get-It...
# 75  https://www.whosampled.com/Beastie-Boys/Get-It...
# 76  https://www.whosampled.com/Kurtis-Blow/If-I-Ru...
# 77  https://www.whosampled.com/The-Beatles/Yellow-...
# 78  https://www.whosampled.com/Funkadelic/Freak-of...
# 79  https://www.whosampled.com/Beastie-Boys/Dis-Yo...
# 80   https://www.whosampled.com/Beastie-Boys/Shadrach
# 81  https://www.whosampled.com/The-Beatles/Come-To...
# 82  https://www.whosampled.com/Kraftwerk/Musique-N...
# 83  https://www.whosampled.com/Marvin-Gaye/Time-to...
# 84  https://www.whosampled.com/Public-Enemy/B-Side...
# 85  https://www.whosampled.com/Public-Enemy/B-Side...
# 86  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 87  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 88  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 89  https://www.whosampled.com/Kool-%26-the-Gang/G...
# 90   https://www.whosampled.com/Kraftwerk/The-Robots/
# 91  https://www.whosampled.com/Kraftwerk/Musique-N...
# 92        https://www.whosampled.com/Run-DMC/The-Ave.
# 93  https://www.whosampled.com/Michael-Jackson/The...
# 94  https://www.whosampled.com/The-J.B.%27s/(It%27...
# 95  https://www.whosampled.com/Michael-Jackson/The...
# 96  https://www.whosampled.com/Michael-Jackson/The...
# 97  https://www.whosampled.com/Michael-Jackson/25-...
# 98  https://www.whosampled.com/Michael-Jackson/25-...
# 99     https://www.whosampled.com/The-Time/Get-It-Up/
#
#                                            song_name  \
# 0                                        Murda Style
# 1                                          Mechanics
# 2                                          Mechanics
# 3                                            MXXXIII
# 4                                       Crystal Cuts
# 5                                         Conquering
# 6                           Tribal Connections Pt. 2
# 7                                           Deranged
# 8                                         Lights Out
# 9                                            So Long
# 10                               Hawt (Getter Remix)
# 11                            Enuff (DJ Fresh Remix)
# 12                                     Military Jazz
# 13                                         Gunrunner
# 14                                     Seventh Sound
# 15                                            Stylee
# 16                                      Angel Voices
# 17                                    No Time 2 Love
# 18                                      The Violater
# 19                                        Prominence
# 20                                   Marche À Suivre
# 21                                     Magoo Opening
# 22                                     Magoo Opening
# 23                                       Party Alarm
# 24                                       Party Alarm
# 25                                             Fotki
# 26                                 How Does It Feel?
# 27                                           Shimmer
# 28                      Fire (Urban Shakedown Remix)
# 29                                        The Dragon
# ..                                               ...
# 70                                          Analysis
# 71                 La Formule Secrète II: Le Retour!
# 72                                    Taken to Heart
# 73                                  Southern Comfort
# 74                                      Still Waters
# 75                        Crimson Stars First Lesson
# 76                                         2 Pumpin'
# 77                          The Bonnie & Clyde Theme
# 78                                           Feel It
# 79                                      Rough Luxury
# 80                       Protection (DJ Narcs Remix)
# 81                                          Lesson 4
# 82                                          Lesson 4
# 83                             Dziękuj Za to Co Masz
# 84                                        Understand
# 85                                            Volcon
# 86                                     Are You Ready
# 87                                   Talking to Gods
# 88                                          Ratatata
# 89                    Ultrafunkula (Ganja Kru Remix)
# 90                                        Footprints
# 91                           Blessings (For My Baby)
# 92                                           Aaron 2
# 93  Under Mi Sensi (Jungle Spliff) (X Project Remix)
# 94                                   Inna Year 3,000
# 95                                        Omega Amen
# 96                                          Break In
# 97   Only When I Lose Myself (Subsonic Legacy Remix)
# 98                                         Reel Funk
# 99                                          Time War
#
#                                              song_url
# 0      https://www.whosampled.com/Kid-Lib/Murda-Style
# 1   https://www.whosampled.com/Dom-%26-Roland/Mech...
# 2   https://www.whosampled.com/Dom-%26-Roland/Mech...
# 3   https://www.whosampled.com/DJ-Groove-(Russia)/...
# 4       https://www.whosampled.com/Sully/Crystal-Cuts
# 5      https://www.whosampled.com/Acid-Lab/Conquering
# 6   https://www.whosampled.com/DJ-Crazee-M/Tribal-...
# 7   https://www.whosampled.com/Special-Request/Der...
# 8   https://www.whosampled.com/III-Most-Wanted/Lig...
# 9             https://www.whosampled.com/Seba/So-Long
# 10  https://www.whosampled.com/Brillz/Hawt-%28Gett...
# 11  https://www.whosampled.com/DJ-Shadow/Enuff-%28...
# 12      https://www.whosampled.com/Plug/Military-Jazz
# 13  https://www.whosampled.com/Gabriel-(Drum-%26-B...
# 14     https://www.whosampled.com/Anile/Seventh-Sound
# 15    https://www.whosampled.com/Soundmurderer/Stylee
# 16  https://www.whosampled.com/Virtual-Self/Angel-...
# 17  https://www.whosampled.com/DJ-Marky/No-Time-2-...
# 18  https://www.whosampled.com/Resonant-Evil/The-V...
# 19     https://www.whosampled.com/Stranjah/Prominence
# 20  https://www.whosampled.com/Sens-Unik/Marche-%C...
# 21  https://www.whosampled.com/Cornelius/Magoo-Ope...
# 22  https://www.whosampled.com/Cornelius/Magoo-Ope...
# 23    https://www.whosampled.com/Downlink/Party-Alarm
# 24    https://www.whosampled.com/Downlink/Party-Alarm
# 25  https://www.whosampled.com/Pijani-Powietrzem/F...
# 26  https://www.whosampled.com/Electroset/How-Does...
# 27   https://www.whosampled.com/Source-Direct/Shimmer
# 28  https://www.whosampled.com/Prizna/Fire-%28Urba...
# 29  https://www.whosampled.com/John-Rolodex/The-Dr...
# ..                                                ...
# 70  https://www.whosampled.com/Technical-Itch/Anal...
# 71  https://www.whosampled.com/Assassin/La-Formule...
# 72      https://www.whosampled.com/KCF/Taken-to-Heart
# 73  https://www.whosampled.com/Innervisions/Southe...
# 74  https://www.whosampled.com/Basic-Influence/Sti...
# 75  https://www.whosampled.com/Dr.-Mario/Crimson-S...
# 76  https://www.whosampled.com/2-Croozin%27/2-Pump...
# 77  https://www.whosampled.com/Yo-Yo/The-Bonnie-%2...
# 78   https://www.whosampled.com/Law-%26-Auder/Feel-It
# 79     https://www.whosampled.com/L.O.E./Rough-Luxury
# 80  https://www.whosampled.com/DannyLO/Protection-...
# 81      https://www.whosampled.com/DJ-Shadow/Lesson-4
# 82      https://www.whosampled.com/DJ-Shadow/Lesson-4
# 83  https://www.whosampled.com/Szybki-Szmal/Dzi%C4...
# 84      https://www.whosampled.com/Om-Unit/Understand
# 85          https://www.whosampled.com/Dub-One/Volcon
# 86  https://www.whosampled.com/Sy-%26-Unknown/Are-...
# 87  https://www.whosampled.com/Invisible-Landscape...
# 88       https://www.whosampled.com/Deadcode/Ratatata
# 89  https://www.whosampled.com/Armand-Van-Helden/U...
# 90  https://www.whosampled.com/Spirit-(Drum-%26-Ba...
# 91  https://www.whosampled.com/Jonny-Dangerously/B...
# 92  https://www.whosampled.com/Venetian-Snares/Aar...
# 93  https://www.whosampled.com/Barrington-Levy/Und...
# 94  https://www.whosampled.com/DJ-Crystl/Inna-Year...
# 95    https://www.whosampled.com/Southstar/Omega-Amen
# 96         https://www.whosampled.com/Cirrus/Break-In
# 97  https://www.whosampled.com/Depeche-Mode/Only-W...
# 98  https://www.whosampled.com/Northern-Connexion/...
# 99    https://www.whosampled.com/Evol-Intent/Time-War
#
# [100 rows x 7 columns]
